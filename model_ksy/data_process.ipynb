# %%
import pandas as pd
import numpy as np

# %%
area = 'Gangnam'

# %%
#rest = pd.read_csv(f'../crawings/area_csv/{area}/rest_concat.csv')
data = pd.read_csv(f'../crawings/user_csv/{area}/user_concat.csv')
#data_concat = pd.merge(data, rest, left_on = 'rest', right_on = 'url', how = "left")
#data_concat = data_concat[~data_concat['rest'].isna()]
data
# Out:
#                                                       link  \
# 0        https://m.place.naver.com/my/6130db4973adbe125...
# 1        https://m.place.naver.com/my/5daf02038f87a842b...
# 2        https://m.place.naver.com/my/5c6fba93cfc813f61...
# 3        https://m.place.naver.com/my/5dcbf9808f87a842b...
# 4        https://m.place.naver.com/my/5dafbac38f87a842b...
# ...                                                    ...
# 1168365  https://m.place.naver.com/my/5c81ce70c8cfbd54c...
# 1168366  https://m.place.naver.com/my/5e743b338f87a842b...
# 1168367  https://m.place.naver.com/my/5e2fdb5a8f87a842b...
# 1168368  https://m.place.naver.com/my/5dcd38d98f87a842b...
# 1168369  https://m.place.naver.com/my/5b9b76308325836de...
#
#                                                       user          rest
# 0        로지씨리뷰 574사진 458팔로워 46팔로우방문자리뷰방문자리뷰방문자리뷰방문자리뷰이전...  1.675303e+09
# 1        딴2리뷰 224사진 303팔로워 7팔로우방문자리뷰방문자리뷰방문자리뷰방문자리뷰방문자리...  1.675303e+09
# 2        제제7225리뷰 56사진 168팔로워 3팔로우방문자리뷰방문자리뷰방문자리뷰방문자리뷰방...  1.675303e+09
# 3        she****리뷰 221사진 424팔로워 32팔로우방문자리뷰방문자리뷰방문자리뷰방문자...  1.675303e+09
# 4        소앵2리뷰 43사진 95팔로워 3팔로우방문자리뷰방문자리뷰방문자리뷰방문자리뷰방문자리뷰...  1.675303e+09
# ...                                                    ...           ...
# 1168365  jina9336리뷰 418팔로우별점5최근 방문일20.5.22.금2020년 5월 22...  2.113500e+07
# 1168366  카키야무리뷰 67사진 3팔로우별점5최근 방문일20.3.3.화2020년 3월 3일 화...  2.113500e+07
# 1168367  ilo****리뷰 773사진 5팔로우별점4최근 방문일20.4.18.토2020년 4월...  2.113500e+07
# 1168368  세잎클로버5035리뷰 250사진 1팔로우별점3최근 방문일20.8.8.토2020년 8...  2.113500e+07
# 1168369  에다므리뷰 85사진 4팔로우별점4최근 방문일19.5.23.목2019년 5월 23일 ...  2.113500e+07
#
# [1168370 rows x 3 columns]
