# %%
import selenium
from selenium import webdriver
from selenium.webdriver import ActionChains

from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

import time
import pandas as pd

# %%
# https://map.naver.com/v5/search/%EA%B0%95%EB%8F%99%EA%B5%AC%20%EA%B0%95%EC%9D%BC%EB%8F%99%20%EC%9D%8C%EC%8B%9D%EC%A0%90?c=14156003.2157876,4518152.8041340,14,0,0,0,dh
# https://map.naver.com/v5/search/%EA%B0%95%EB%8F%99%EA%B5%AC%20%EC%83%81%EC%9D%BC%EB%8F%99%20%EC%9D%8C%EC%8B%9D%EC%A0%90?c=14153722.2920998,4515621.4603014,13.54,0,0,0,dh
# https://map.naver.com/v5/search/%EA%B0%95%EB%8F%99%EA%B5%AC%20%EB%AA%85%EC%9D%BC%EB%8F%99%20%EC%9D%8C%EC%8B%9D%EC%A0%90?c=14153180.2476846,4516224.3543881,15,0,0,0,dh
# https://map.naver.com/v5/search/%EA%B0%95%EB%8F%99%EA%B5%AC%20%EA%B3%A0%EB%8D%95%EB%8F%99%20%EC%9D%8C%EC%8B%9D%EC%A0%90?c=14153512.9097233,4517068.8236271,14,0,0,0,dh
# https://map.naver.com/v5/search/%EA%B0%95%EB%8F%99%EA%B5%AC%20%EC%95%94%EC%82%AC%EB%8F%99%20%EC%9D%8C%EC%8B%9D%EC%A0%90?c=14151877.5202116,4516261.2405718,15,0,0,0,dh
# https://map.naver.com/v5/search/%EA%B0%95%EB%8F%99%EA%B5%AC%20%EC%B2%9C%ED%98%B8%EB%8F%99%20%EC%9D%8C%EC%8B%9D%EC%A0%90?c=14151872.9955127,4515349.7111196,14,0,0,0,dh
# https://map.naver.com/v5/search/%EA%B0%95%EB%8F%99%EA%B5%AC%20%EC%84%B1%EB%82%B4%EB%8F%99%20%EC%9D%8C%EC%8B%9D%EC%A0%90?c=14150737.8312652,4513303.6958368,15,0,0,0,dh
# https://map.naver.com/v5/search/%EA%B0%95%EB%8F%99%EA%B5%AC%20%EA%B8%B8%EB%8F%99%20%EC%9D%8C%EC%8B%9D%EC%A0%90?c=14152526.7192224,4513881.7793561,14,0,0,0,dh
# https://map.naver.com/v5/search/%EA%B0%95%EB%8F%99%EA%B5%AC%20%EB%91%94%EC%B4%8C%EB%8F%99%20%EC%9D%8C%EC%8B%9D%EC%A0%90?c=14152915.2516371,4513714.1387279,15,0,0,0,dh

# %%
from selenium.webdriver.chrome.options import Options
chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# executable_path : /opt/ml/crawling/chromedriver
# https://map.naver.com/v5/search/%EA%B0%95%EB%8F%99%EA%B5%AC%20%EC%84%B1%EB%82%B4%EB%8F%99%20%EC%9D%8C%EC%8B%9D%EC%A0%90?c=14150737.8312652,4513303.6958368,15,0,0,0,dh
# https://map.naver.com/v5/search/%EA%B0%95%EB%8F%99%EA%B5%AC%20%EA%B8%B8%EB%8F%99%20%EC%9D%8C%EC%8B%9D%EC%A0%90?c=14152526.7192224,4513881.7793561,14,0,0,0,dh
# https://map.naver.com/v5/search/%EA%B0%95%EB%8F%99%EA%B5%AC%20%EB%91%94%EC%B4%8C%EB%8F%99%20%EC%9D%8C%EC%8B%9D%EC%A0%90?c=14152915.2516371,4513714.1387279,15,0,0,0,dh
driver = webdriver.Chrome(executable_path='/opt/ml/input/final/chromedriver', chrome_options=chrome_options)
URL = "https://map.naver.com/v5/search/%EA%B0%95%EB%8F%99%EA%B5%AC%20%EC%95%94%EC%82%AC%EB%8F%99%20%EC%9D%8C%EC%8B%9D%EC%A0%90?c=14151877.5202116,4516261.2405718,15,0,0,0,dh"  
driver.get(URL)

# %%
driver.switch_to.frame('searchIframe') #iframe 으로 이동하기 위한 코드
restaurants_list = pd.DataFrame()

# %%
from tqdm import tqdm
epoch = 6 # 6이 최대인듯
for _ in tqdm(range(epoch)):
    click_list = driver.find_elements(By.CLASS_NAME, "tzwk0")
    click_list[0].click() #아무거나 클릭을 해야 end키가 먹혀서 임의로 아무 클래스 클릭한거임
    for _ in range(10):
        driver.find_element(By.CSS_SELECTOR, "body").send_keys(Keys.END) # end키를 눌러서 아래까지 로딩
    time.sleep(2)
    click_list = driver.find_elements(By.CLASS_NAME, "tzwk0") # 식당 리스트
    name_list = driver.find_elements(By.CLASS_NAME, "TYaxT") # 식당 이름 리스트
    name_list = [user.text for user in name_list]
    tag_list = driver.find_elements(By.CLASS_NAME, "KCMnt") # 식당 종류 리스트
    tag_list = [user.text for user in tag_list]
    review_list = driver.find_elements(By.CLASS_NAME, "MVx6e") # 리뷰 개수 리스트
    review_list = [user.text.split("\n")[-1] for user in review_list]
    url_list = []
    for restaurant_link in click_list:
        restaurant_link.click()
        url_list.append(driver.current_url)
        time.sleep(0.5)
    restaurants_list2 = pd.DataFrame({'restaurant' : name_list, 'tag' : tag_list, 'url' : url_list, 'review' : review_list}, dtype = str)
    restaurants_list = pd.concat([restaurants_list, restaurants_list2], axis = 0, sort=False)
    driver.find_elements(By.CLASS_NAME, "yUtES")[1].click() #다음페이지 클릭
    time.sleep(2)
# Out:
# 100%|██████████| 6/6 [04:03<00:00, 40.66s/it]

# %%
restaurants_list[:10]
# Out:
#        restaurant       tag  \
# 0      미테이블 강동직영점        양식
# 1            멘야세븐     일본식라면
# 2          영화정해장국       해장국
# 3       라라브레드 길동점      베이커리
# 4              어흥      요리주점
# 5          소문난칼국수    칼국수,만두
# 6              한주      요리주점
# 7  제주은희네해장국 강동길동점       해장국
# 8             비타밀  다이어트,샐러드
# 9            으뜸횟집       생선회
#
#                                                  url  \
# 0  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# 1  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# 2  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# 3  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# 4  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# 5  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# 6  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# 7  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# 8  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# 9  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
#
#                                review
# ...

# %%
restaurants_list.to_csv('./area_csv/KongDong/rest5.csv', index=False)

# %%
restaurants_list
# Out:
#       restaurant       tag                                                url  \
# 0   텍사스데브라질 압구정점    스테이크,립  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# 1        미뉴트 빠삐용    카페,디저트  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# 2             까폼      태국음식  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# 3         노티드 청담        카페  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# 4            뱃고동      낙지요리  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# ..           ...       ...                                                ...
# 45         타코앤칠리  멕시코,남미음식  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# 46        엘피노323  멕시코,남미음식  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# 47       낭만옵빠 신사     오뎅,꼬치  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# 48           미라이       일식당  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
# 49        레 부르주아        와인  https://map.naver.com/v5/search/%EA%B0%95%EB%8...
#
#                        review
# ...
